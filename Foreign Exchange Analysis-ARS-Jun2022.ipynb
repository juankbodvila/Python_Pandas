# %%
import pandas as pd
import matplotlib.pyplot as plt

tipo_cambio = pd.read_csv('tipo_cambio_a3500.csv',)
tipo_cambio
# Out:
#      indice_tiempo  tipo_cambio_bna_vendedor  tipo_cambio_a3500  \
# 0       2002-03-05                       NaN             1.9917
# 1       2002-03-06                       NaN             2.0508
# 2       2002-03-07                       NaN             2.1375
# 3       2002-03-08                       NaN             2.2033
# 4       2002-03-09                       NaN             2.2033
# ...            ...                       ...                ...
# 7388    2022-05-27                    124.50           119.5583
# 7389    2022-05-28                    124.50           119.5583
# 7390    2022-05-29                    124.50           119.5583
# 7391    2022-05-30                    125.00           120.0050
# 7392    2022-05-31                    125.25           120.1617
#
#       tipo_cambio_mae  volumen_mae  tipo_cambio_implicito_en_adrs  \
# 0                 NaN          NaN                       2.180124
# ...

# %%
tipo_cambio.set_index('indice_tiempo', inplace=True)
tipo_cambio
# Out:
#                tipo_cambio_bna_vendedor  tipo_cambio_a3500  tipo_cambio_mae  \
# indice_tiempo
# 2002-03-05                          NaN             1.9917              NaN
# 2002-03-06                          NaN             2.0508              NaN
# 2002-03-07                          NaN             2.1375              NaN
# 2002-03-08                          NaN             2.2033              NaN
# 2002-03-09                          NaN             2.2033              NaN
# ...                                 ...                ...              ...
# 2022-05-27                       124.50           119.5583           119.55
# 2022-05-28                       124.50           119.5583           119.55
# 2022-05-29                       124.50           119.5583           119.55
# 2022-05-30                       125.00           120.0050           119.55
# 2022-05-31                       125.25           120.1617           120.20
#
# ...

# %%
#analisis grafico

tipo_cambio['tipo_cambio_a3500'].plot(kind='line',figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='indice_tiempo'>
